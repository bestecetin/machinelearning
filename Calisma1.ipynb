# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv("/Users/bestecetin/Desktop/machine_learning/The Top Billionaires.csv")
import seaborn as sns

# %%
data.head()
# Out:
#               NAME   2018   2019   2020   2021   2022
# 0        Elon Musk   19.9   22.3   24.6  151.0  219.0
# 1       Jeff Bezos  112.0  131.0  113.0  177.0  171.0
# 2  Bernard Arnault   72.0   76.0   76.0  150.0  158.0
# 3       Bill Gates   90.0   96.5   98.0  124.0  129.0
# 4   Warren Buffett   84.0   82.5   67.5   96.0  118.0

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=data,x="NAME",y="2018",label="2018")
sns.lineplot(data=data,x="NAME",y="2019",label="2019")
sns.lineplot(data=data,x="NAME",y="2020",label="2020")
sns.lineplot(data=data,x="NAME",y="2021",label="2021")
sns.lineplot(data=data,x="NAME",y="2022",label="2022")
# Out:
# <AxesSubplot:xlabel='NAME', ylabel='2018'>
